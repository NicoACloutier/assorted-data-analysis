# %%
import pandas as pd
import torch
from torch import nn
from gensim.models import Word2Vec
import functools
import numpy as np
import re

# %%
MAX_LENGTH = 20
BATCH_SIZE = 500
TRAIN_DATA_PATH = '..\\data\\train.csv'
NUM_SPLITS = 7
LEARNING_RATE = 0.001
MODEL_DIR = '.\\saves'
letter_vectors = Word2Vec.load('..\\preprocessing\\word2vec.model') #load word2vec model

# %%
fill_out = lambda word, max_length: word + ' ' * (max_length - len(word)) #add spaces until a word is 25 characters long

#remove forbidden characters from a string
def clean_string(string, forbidden_chars):
    for char in forbidden_chars:
        string = string.replace(char, '')
    return string

#convert word to matrix
@functools.cache
def convert_to_matrix(word):
    return [letter_vectors.wv[letter] for letter in word]

#convert the raw text data into cleaned pytorch tensor word2vecs
def convert_data(df):
    df = df.astype(str)
    #remove characters not in the word2vec model
    text = ''.join(list(df['Clue'])) + ''.join(list(df['Answer']))
    chars = list(set(text))
    forbidden_chars = [char for char in chars if char not in letter_vectors.wv]
    df['Clue'] = df['Clue'].apply(lambda x: clean_string(x, forbidden_chars))
    df['Answer'] = df['Answer'].apply(lambda x: clean_string(x, forbidden_chars))
    df['Obscured'] = df['Obscured'].apply(lambda x: clean_string(x, forbidden_chars))
    
    #fill clues and answers to max length
    df['Clue'] = df['Clue'].apply(lambda x: fill_out(x, MAX_LENGTH))
    df['Answer'] = df['Answer'].apply(lambda x: fill_out(x, MAX_LENGTH))
    df['Obscured'] = df['Obscured'].apply(lambda x: fill_out(x, MAX_LENGTH))
    
    rows = [row for (_, row) in df.iterrows()]
    
    source = [convert_to_matrix(row['Clue']) + convert_to_matrix(row['Obscured']) for row in rows]
    target = [convert_to_matrix(row['Answer']) for row in rows]
    
    #convert data to pytorch tensors
    source = torch.as_tensor(np.array(source))
    target = torch.as_tensor(np.array(target))
    
    return source, target

#convert a pytorch tensor of word2vec letters into a string
def tensor_to_word(input_tensor):
    word = ''
    input_list = input_tensor.tolist()
    for word2vec in input_list:
        letter_vector = np.array(word2vec)
        letter = letter_vectors.wv.most_similar(positive=[letter_vector], topn=1)[0]
        word += letter[0]
    word = re.sub('"+', '', word)
    return word

# %%
def evaluate_model(split, number_splits, df):
    checkpoint = torch.load(f'{MODEL_DIR}\\{split}.pth',
                           map_location=torch.device('cpu'))
    
    model = nn.Transformer(d_model=10, nhead=5) #initialize transformer model
    criterion = nn.MSELoss() 
    optimizer = torch.optim.SGD(model.parameters(), lr=LEARNING_RATE) 
    
    model.load_state_dict(checkpoint['model_state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    model.eval()
    
    #select only the data this model was not trained on
    jump = len(df) // number_splits
    begin = jump*split
    end = jump*(split+1)
    df = df.iloc[begin:end]
    df = df.reset_index()
    df = df.iloc[:2500] #only get the first 2,500, just to get an idea
    
    source, target = convert_data(df)
    length = len(source)
    
    avg_loss = 0
    for i, (sequence, answer) in enumerate(zip(source, target)):
        output = model.forward(sequence, answer)
        loss = criterion(output, answer)
        avg_loss += loss
        
        if (i+1) % BATCH_SIZE == 0:
            avg_loss /= BATCH_SIZE
            word = tensor_to_word(output)
            print(f'Iteration number {i+1} of {length}. Average loss: {avg_loss}.')
            print(f'Sample row:')
            print(df.iloc[i])
            print(f'Given answer: {word}.\n')

# %%
def main():
    df = pd.read_csv(TRAIN_DATA_PATH) #initially cross-validate on unseen train data
    with torch.no_grad():
        for split in range(NUM_SPLITS):
            print(f'\n\n SPLIT {split}\n\n')
            try:
                evaluate_model(split, NUM_SPLITS, df)
            except Exception: #in case the model isn't trained yet, just skip it
                continue

# %%
if __name__ == '__main__':
    main()
# Out:
#  SPLIT 0
#
#
# Iteration number 500 of 2500. Average loss: 1.7745702266693115.
# Sample row:
# index                        499
# Clue        work incorporated in
# Answer                  odetojoy
# Obscured                ________
# Name: 499, dtype: object
# Given answer: eketejey.
#
# Iteration number 1000 of 2500. Average loss: 1.7736705541610718.
# Sample row:
# index                   999
# Clue        buttoned weapon
# Answer                 epee
# Obscured               epee
# Name: 999, dtype: object
# Given answer: ekee.
#
# Iteration number 1500 of 2500. Average loss: 1.76595938205719.
# Sample row:
# index                       1499
# Clue        cultural center esta
# Answer                      moma
# Obscured                    moma
# Name: 1499, dtype: object
# Given answer: keke.
#
# Iteration number 2000 of 2500. Average loss: 1.76057767868042.
# Sample row:
# index                     1999
# Clue        self-righteous one
# Answer                pharisee
# Obscured              ________
# Name: 1999, dtype: object
# Given answer: khesekee.
#
# Iteration number 2500 of 2500. Average loss: 1.778306484222412.
# Sample row:
# index                       2499
# Clue        weapon with a bell g
# Answer                      epee
# Obscured                    __ee
# Name: 2499, dtype: object
# Given answer: ekee.
#
#
#
#  SPLIT 1
#
#
# Iteration number 500 of 2500. Average loss: 1.7789357900619507.
# Sample row:
# index                     220046
# Clue        maurice ___, of nixo
# Answer                     stans
# Obscured                   _____
# Name: 499, dtype: object
# Given answer: ktekk.
#
# Iteration number 1000 of 2500. Average loss: 1.7652851343154907.
# Sample row:
# index                     220546
# Clue        what cribs are used
# Answer                     exams
# Obscured                   ex_m_
# Name: 999, dtype: object
# Given answer: esekk.
#
# Iteration number 1500 of 2500. Average loss: 1.779362440109253.
# Sample row:
# index                     221046
# Clue        "platoon" movie stud
# Answer                     orion
# Obscured                   ___on
# Name: 1499, dtype: object
# Given answer: eseek.
#
# Iteration number 2000 of 2500. Average loss: 1.7779603004455566.
# Sample row:
# index                     221546
# Clue        sea of okhotsk feede
# Answer                      amur
# Obscured                    _m_r
# Name: 1999, dtype: object
# Given answer: ekus.
#
# Iteration number 2500 of 2500. Average loss: 1.7958879470825195.
# Sample row:
# index                   222046
# Clue        object of a tuneup
# Answer                  engine
# Obscured                _n__ne
# Name: 2499, dtype: object
# Given answer: ekkeke.
#
#
#
#  SPLIT 2
#
#
# Iteration number 500 of 2500. Average loss: 1.7146908044815063.
# Sample row:
# index               439593
# Clue        branch of sci.
# Answer                biol
# Obscured              b_ol
# Name: 499, dtype: object
# Given answer: jeek.
#
# Iteration number 1000 of 2500. Average loss: 1.7395621538162231.
# Sample row:
# index                     440093
# Clue        in a narrowly morali
# Answer           selfrighteously
# Obscured         _______________
# Name: 999, dtype: object
# Given answer: kektsekhteeukky.
#
# Iteration number 1500 of 2500. Average loss: 1.7388736009597778.
# Sample row:
# index                     440593
# Clue        loafer that should b
# Answer                      shoe
# Obscured                    s___
# Name: 1499, dtype: object
# Given answer: khee.
#
# Iteration number 2000 of 2500. Average loss: 1.7312294244766235.
# Sample row:
# index                    441093
# Clue        mandolin's ancestor
# Answer                     lute
# Obscured                   lute
# Name: 1999, dtype: object
# Given answer: kuke.
#
# Iteration number 2500 of 2500. Average loss: 1.7537959814071655.
# Sample row:
# index                     441593
# Clue        word with pool or po
# Answer                       car
# Obscured                     _a_
# Name: 2499, dtype: object
# Given answer: kes.
#
#
#
#  SPLIT 3
#
#
#
#
#  SPLIT 4
#
#
# Iteration number 500 of 2500. Average loss: 1.7368123531341553.
# Sample row:
# index                     878687
# Clue        idle stretch for an
# Answer                   byeweek
# Obscured                 _______
# Name: 499, dtype: object
# Given answer: jyeweek.
#
# Iteration number 1000 of 2500. Average loss: 1.7420759201049805.
# Sample row:
# index                     879187
# Clue        african nation since
# Answer                   eritrea
# Obscured                 erit_ea
# Name: 999, dtype: object
# Given answer: esetsee.
#
# Iteration number 1500 of 2500. Average loss: 1.7389081716537476.
# Sample row:
# index                 879687
# Clue        stage statuettes
# Answer                 tonys
# Obscured               t____
# Name: 1499, dtype: object
# Given answer: tekyk.
#
# Iteration number 2000 of 2500. Average loss: 1.7377204895019531.
# Sample row:
# index                   880187
# Clue        shakespearean trio
# Answer         theweirdsisters
# Obscured       _hewei_dsisters
# Name: 1999, dtype: object
# Given answer: theweeskkektesk.
#
# Iteration number 2500 of 2500. Average loss: 1.7481129169464111.
# Sample row:
# index               880687
# Clue        many a tv clip
# Answer               promo
# Obscured             _romo
# Name: 2499, dtype: object
# Given answer: kseke.
#
#
#
#  SPLIT 5
#
#
# Iteration number 500 of 2500. Average loss: 1.7111778259277344.
# Sample row:
# index                    1098234
# Clue        hamburger medium-rar
# Answer                     order
# Obscured                   _r__r
# Name: 499, dtype: object
# Given answer: eskes.
#
# Iteration number 1000 of 2500. Average loss: 1.7019996643066406.
# Sample row:
# index                    1098734
# Clue        where suckers lure p
# Answer                candystore
# Obscured              ___dy_tor_
# Name: 999, dtype: object
# Given answer: kekkyktese.
#
# Iteration number 1500 of 2500. Average loss: 1.7014285326004028.
# Sample row:
# index                    1099234
# Clue        "as you like it" phr
# Answer                   totaste
# Obscured                 _______
# Name: 1499, dtype: object
# Given answer: tetekte.
#
# Iteration number 2000 of 2500. Average loss: 1.7118831872940063.
# Sample row:
# index                 1099734
# Clue        ed.'s convenience
# Answer                   sase
# Obscured                 sase
# Name: 1999, dtype: object
# Given answer: keke.
#
# Iteration number 2500 of 2500. Average loss: 1.7050302028656006.
# Sample row:
# index                 1100234
# Clue        antioxidant berry
# Answer                   acai
# Obscured                 a_ai
# Name: 2499, dtype: object
# Given answer: ekee.
#
#
#
#  SPLIT 6
#
#
# Iteration number 500 of 2500. Average loss: 1.7116870880126953.
# Sample row:
# index                  1317781
# Clue        home theater brand
# Answer                     rca
# Obscured                   r_a
# Name: 499, dtype: object
# Given answer: ske.
#
# Iteration number 1000 of 2500. Average loss: 1.7059967517852783.
# Sample row:
# index                    1318281
# Clue        rulers like juan car
# Answer                     reyes
# Obscured                   r____
# Name: 999, dtype: object
# Given answer: seyek.
#
# Iteration number 1500 of 2500. Average loss: 1.702001690864563.
# Sample row:
# index       1318781
# Clue         shears
# Answer        clips
# Obscured      c_i_s
# Name: 1499, dtype: object
# Given answer: kkekk.
#
# Iteration number 2000 of 2500. Average loss: 1.7054697275161743.
# Sample row:
# index               1319281
# Clue        overly partisan
# Answer          tooonesided
# Obscured        ________d_d
# Name: 1999, dtype: object
# Given answer: teeekesekek.
#
# Iteration number 2500 of 2500. Average loss: 1.6914602518081665.
# Sample row:
# index                1319781
# Clue        buccaneer's base
# Answer                 tampa
# Obscured               _____
# Name: 2499, dtype: object
# Given answer: tekke.
